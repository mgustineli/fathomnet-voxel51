# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
from fathomnet_voxel51.check_gcp_auth import check_gcp_auth

load_dotenv("../.env")

check_gcp_auth()
# Out:
# Checking auth for credentials: Using Default/User Auth
# /Users/mgustineli/github/fathomnet-voxel51/.venv/lib/python3.11/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ✅ SUCCESS! Authenticated with Project ID: computer-vision-team
# ✅ Verified access to bucket: gs://voxel51-test

# %%
from fathomnet_voxel51.upload_to_gcs import process_split

# CONFIGURATION
BUCKET_NAME = "voxel51-test"

# load a subset of the data to test the code
train_json = "../data/dataset_train.json"
test_json = "../data/dataset_test.json"
limit = 100

await process_split(train_json, "train", limit)
# Out:
# Checking existing files in gs://voxel51-test/fathomnet/train_images/...
# /Users/mgustineli/github/fathomnet-voxel51/.venv/lib/python3.11/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Found 8981 existing files.
# Loading ../data/dataset_train.json for split 'train'...
# Limiting to first 100 images.
# Skipping 100 already uploaded images.
# Split 'train' complete: 0 uploaded, 100 skipped.
